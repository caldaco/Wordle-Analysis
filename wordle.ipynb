# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import re

pd.set_option('display.max_columns', 500)

# For plotting
from itertools import cycle

plt.style.use("ggplot")
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %% [markdown]
# # Load in the DataSet & Parse Tweet Text

# %%
tweets = pd.read_csv('C:/Users/ldaco/Documents/tweets.csv')

# %%
def process_tweets(tweets):
    tweets["tweet_datetime"] = pd.to_datetime(tweets["tweet_date"])
    tweets["tweet_date"] = tweets["tweet_datetime"].dt.date
    tweets['wordle_id'] = tweets['tweet_text'].str[:10]
    tweets['n_attempts'] = tweets['tweet_text'].str[11].astype('int')
    tweets['id'] = tweets['tweet_text'].str[7:10].astype('int')
    return tweets
    
tweets = process_tweets(tweets)

# %% [markdown]
# ## How many tweets do we have for each  day

# %%
# tweets['tweet_date'].value_counts() \
    .plot(figsize=(10,5), title="Wordle Tweets by Day",
          color=color_pal[2], lw=1)
plt.show()

# %% [markdown]
# ## Number of Attempts Analysis

# %%
tweets.groupby('wordle_id')['n_attempts'].value_counts() \
    .unstack() \
    .style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_6a2a0_row0_col0, #T_6a2a0_row193_col4, #T_6a2a0_row233_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_6a2a0_row0_col1, #T_6a2a0_row301_col4 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_6a2a0_row0_col2, #T_6a2a0_row1_col2, #T_6a2a0_row2_col2, #T_6a2a0_row3_col3, #T_6a2a0_row4_col1, #T_6a2a0_row5_col2, #T_6a2a0_row6_col2, #T_6a2a0_row7_col2, #T_6a2a0_row8_col2, #T_6a2a0_row9_col3, #T_6a2a0_row10_col2, #T_6a2a0_row11_col2, #T_6a2a0_row12_col2, #T_6a2a0_row13_col2, #T_6a2a0_row14_col2, #T_6a2a0_row15_col2, #T_6a2a0_row16_col1, #T_6a2a0_row17_col1, #T_6a2a0_row18_col1, #T_6a2a0_row19_col2, #T_6a2a0_row20_col2, #T_6a2a0_row21_col2, #T_6a2a0_row22_col2, #T_6a2a0_row23_col3, #T_6a2a0_row24_col2, #T_6a2a0_row25_col2, #T_6a2a0_row26_col2, #T_6a2a0_row27_col2, #T_6a2a0_row28_col2, #T_6a2a0_row29_col2, #T_6a2a0_row30_col3, #T_6a2a0_row31_col2, #T_6a2a0_row32_col2, #T_6a2a0_row33_col2, #T_6a2a0_row34_col2, #T_6a2a0_row35_col3, #T_6a2a0_row36_col2, #T_6a2a0_row37_col2, #T_6a2a0_row38_col1, #T_6a2a0_row39_col2, #T_6a2a0_row40_col2, #T_6a2a0_row41_col3, #T_6a2a0_row42_col2, #T_6a2a0_row43_col2, #T_6a2a0_row44_col2, #T_6a2a0_row45_col2, #T_6a2a0_row46_col2, #T_6a2a0_row47_col2, #T_6a2a0_row48_col2, #T_6a2a0_row49_col2, #T_6a2a0_row50_col2, #T_6a2a0_row51_col2, #T_6a2a0_row52_col2, #T_6a2a0_row53_col2, #T_6a2a0_row54_col2, #T_6a2a0_row55_col2, #T_6a2a0_row56_col2, #T_6a2a0_row57_col2, #T_6a2a0_row58_col2, #T_6a2a0_row59_col1, #T_6a2a0_row60_col2, #T_6a2a0_row61_col2, #T_6a2a0_row62_col2, #T_6a2a0_row63_col2, #T_6a2a0_row64_col2, #T_6a2a0_row65_col1, #T_6a2a0_row66_col2, #T_6a2a0_row67_col2, #T_6a2a0_row68_col2, #T_6a2a0_row69_col3, #T_6a2a0_row70_col2, #T_6a2a0_row71_col2, #T_6a2a0_row72_col2, #T_6a2a0_row73_col3, #T_6a2a0_row74_col3, #T_6a2a0_row75_col2, #T_6a2a0_row76_col1, #T_6a2a0_row77_col2, #T_6a2a0_row78_col2, #T_6a2a0_row79_col3, #T_6a2a0_row80_col3, #T_6a2a0_row81_col2, #T_6a2a0_row82_col1, #T_6a2a0_row83_col2, #T_6a2a0_row84_col2, #T_6a2a0_row85_col2, #T_6a2a0_row86_col2, #T_6a2a0_row87_col2, #T_6a2a0_row88_col2, #T_6a2a0_row89_col2, #T_6a2a0_row90_col2, #T_6a2a0_row91_col2, #T_6a2a0_row92_col4, #T_6a2a0_row93_col2, #T_6a2a0_row94_col3, #T_6a2a0_row95_col1, #T_6a2a0_row96_col2, #T_6a2a0_row97_col2, #T_6a2a0_row98_col3, #T_6a2a0_row99_col2, #T_6a2a0_row100_col2, #T_6a2a0_row101_col3, #T_6a2a0_row102_col1, #T_6a2a0_row103_col3, #T_6a2a0_row104_col3, #T_6a2a0_row105_col2, #T_6a2a0_row106_col2, #T_6a2a0_row107_col1, #T_6a2a0_row108_col2, #T_6a2a0_row109_col2, #T_6a2a0_row110_col2, #T_6a2a0_row111_col3, #T_6a2a0_row112_col1, #T_6a2a0_row113_col2, #T_6a2a0_row114_col2, #T_6a2a0_row115_col2, #T_6a2a0_row116_col2, #T_6a2a0_row117_col2, #T_6a2a0_row118_col2, #T_6a2a0_row119_col3, #T_6a2a0_row120_col2, #T_6a2a0_row121_col2, #T_6a2a0_row122_col2, #T_6a2a0_row123_col2, #T_6a2a0_row124_col2, #T_6a2a0_row125_col2, #T_6a2a0_row126_col2, #T_6a2a0_row127_col2, #T_6a2a0_row128_col3, #T_6a2a0_row129_col2, #T_6a2a0_row130_col1, #T_6a2a0_row131_col2, #T_6a2a0_row132_col2, #T_6a2a0_row133_col2, #T_6a2a0_row134_col2, #T_6a2a0_row135_col2, #T_6a2a0_row136_col2, #T_6a2a0_row137_col1, #T_6a2a0_row138_col2, #T_6a2a0_row139_col2, #T_6a2a0_row140_col2, #T_6a2a0_row141_col2, #T_6a2a0_row142_col2, #T_6a2a0_row143_col2, #T_6a2a0_row144_col2, #T_6a2a0_row145_col3, #T_6a2a0_row146_col2, #T_6a2a0_row147_col2, #T_6a2a0_row148_col1, #T_6a2a0_row149_col2, #T_6a2a0_row150_col2, #T_6a2a0_row151_col2, #T_6a2a0_row152_col3, #T_6a2a0_row153_col2, #T_6a2a0_row154_col2, #T_6a2a0_row155_col2, #T_6a2a0_row156_col2, #T_6a2a0_row157_col2, #T_6a2a0_row158_col2, #T_6a2a0_row159_col2, #T_6a2a0_row160_col1, #T_6a2a0_row161_col2, #T_6a2a0_row162_col2, #T_6a2a0_row163_col3, #T_6a2a0_row164_col3, #T_6a2a0_row165_col2, #T_6a2a0_row166_col3, #T_6a2a0_row167_col2, #T_6a2a0_row168_col3, #T_6a2a0_row169_col2, #T_6a2a0_row170_col3, #T_6a2a0_row171_col2, #T_6a2a0_row172_col2, #T_6a2a0_row173_col2, #T_6a2a0_row174_col2, #T_6a2a0_row175_col3, #T_6a2a0_row176_col1, #T_6a2a0_row177_col2, #T_6a2a0_row178_col2, #T_6a2a0_row179_col3, #T_6a2a0_row180_col2, #T_6a2a0_row181_col2, #T_6a2a0_row182_col2, #T_6a2a0_row183_col2, #T_6a2a0_row184_col3, #T_6a2a0_row185_col2, #T_6a2a0_row186_co ...
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6a2a0_row0_col3, #T_6a2a0_row32_col4, #T_6a2a0_row188_col4 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_6a2a0_row0_col4, #T_6a2a0_row1_col0, #T_6a2a0_row2_col4, #T_6a2a0_row3_col0, #T_6a2a0_row4_col4, #T_6a2a0_row5_col4, #T_6a2a0_row6_col4, #T_6a2a0_row7_col0, #T_6a2a0_row8_col0, #T_6a2a0_row9_col0, #T_6a2a0_row10_col0, #T_6a2a0_row11_col0, #T_6a2a0_row12_col4, #T_6a2a0_row13_col0, #T_6a2a0_row14_col0, #T_6a2a0_row15_col0, #T_6a2a0_row16_col4, #T_6a2a0_row17_col4, #T_6a2a0_row18_col4, #T_6a2a0_row19_col0, #T_6a2a0_row20_col4, #T_6a2a0_row21_col0, #T_6a2a0_row22_col0, #T_6a2a0_row23_col0, #T_6a2a0_row24_col0, #T_6a2a0_row25_col0, #T_6a2a0_row26_col0, #T_6a2a0_row27_col0, #T_6a2a0_row28_col0, #T_6a2a0_row29_col0, #T_6a2a0_row30_col0, #T_6a2a0_row31_col0, #T_6a2a0_row32_col0, #T_6a2a0_row33_col0, #T_6a2a0_row34_col0, #T_6a2a0_row35_col0, #T_6a2a0_row36_col0, #T_6a2a0_row37_col0, #T_6a2a0_row37_col4, #T_6a2a0_row38_col4, #T_6a2a0_row39_col0, #T_6a2a0_row40_col0, #T_6a2a0_row41_col0, #T_6a2a0_row42_col0, #T_6a2a0_row43_col4, #T_6a2a0_row44_col4, #T_6a2a0_row45_col0, #T_6a2a0

# %% [markdown]
# ## How many attempts does it usually take?

# %%
ax = tweets['n_attempts'].value_counts() \
    .sort_index() \
    .plot(figsize=(10,5), 
          kind='bar',
          title = 'Number of Wordle Attempts',
          edgecolor = 'black')

ax.set_xlabel('Attempts Solved in')
ax.set_ylabel('Number of Tweets')
plt.show()

# %% [markdown]
# # Parse tweet Text

# %%
# Make dark squares consistent
tweets['tweet_text'] = tweets['tweet_text'].str.replace('⬜','⬛')

# %%
def parse_tweet_text(tweets):
    for n in range(6):
        n += 1
        tweets[f'has_guess{n}'] = tweets['tweet_text'].str.split('\n').str[n+1] \
            .str.contains('|'.join(['🟨','⬛','🟩'])) \
            .fillna(False)

        tweets.loc[tweets[f'has_guess{n}'], f'guess{n}'] = \
                tweets['tweet_text'].str.split('\n').str[n + 1].str[:5]
        tweets.loc[tweets[f'has_guess{n}'],
                       f'guess{n}_incorrect'] = tweets[f'guess{n}'].str.count('⬛')
        tweets.loc[tweets[f'has_guess{n}'],
                   f'guess{n}_wrong_spot'] = tweets[f'guess{n}'].str.count('🟨')
        tweets.loc[tweets[f'has_guess{n}'],
                   f'guess{n}_correct'] = tweets[f'guess{n}'].str.count('🟩')

        tweets.loc[tweets[f'guess{n}_correct'] == 6, 'final_guess'] = n
    return tweets

tweets = parse_tweet_text(tweets)
# Out:
# C:\Users\ldaco\AppData\Local\Temp\ipykernel_8516\3771641665.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
# C:\Users\ldaco\AppData\Local\Temp\ipykernel_8516\3771641665.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
# C:\Users\ldaco\AppData\Local\Temp\ipykernel_8516\3771641665.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)
# C:\Users\ldaco\AppData\Local\Temp\ipykernel_8516\3771641665.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(False)

# %%
# Keep additional tweet text
tweets['additional_text'] = \
    tweets.loc[~tweets['tweet_text'] \
    .str.split('\n').str[-1].str.contains('🟩')] \
    ['tweet_text'].str.split('\n').str[-1]

# %% [markdown]
# # Plot results by Attempt

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 5), sharex=True)

for i, x in enumerate(['_correct','_wrong_spot','_incorrect']):
    col_subset = [c for c in tweets.columns if x in c]
    guess_avg = tweets[col_subset].mean()
    guess_avg.index = [f'Guess {i+1}' for i in range(6)]
    guess_avg.sort_index(ascending=False) \
        .plot(kind='barh',
              title=f'{x.strip("_").replace("_"," ").title()}',
              ax=axs[i],
              color=color_pal[i+1])
    axs[i].set_xlabel('Average Letters')
fig.suptitle('Wordle Average Results by Guess Number', fontsize=18)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Letter Analysis

# %%
answer_dict = {252 : 'SPILL',
     251 : 'VIVID',
     250 : 'BLOKE',
     249 : 'TROVE',
     248 : 'THORN',
     247 : 'OTHER',
     246 : 'TACIT',
     245 : 'SWILL',
     244 : 'DODGE',
     243 : 'SHAKE',
     242 : 'CAULK',
     241 : 'AROMA',
     240 : 'CYNIC',
     239 : 'ROBIN',
     238 : 'ULTRA',
     237 : 'ULCER',
     236 : 'PAUSE',
     235 : 'HUMOR',
     234 : 'FRAME',
     233 : 'ELDER',
     232 : 'SKILL',
     231 : 'ALOFT',
     230 : 'PLEAT',
     229 : 'SHARD',
     228 : 'MOIST',
     227 : 'THOSE',
     204 : 'GORGE',
     205 : 'QUERY',
     206 : 'DRINK',
     207 : 'FAVOR',
     208 : 'ABBEY',
     209 : 'TANGY',
     210 : 'PANIC',
     211 : 'SOLAR',
     212 : 'SHIRE',
     213 : 'PROXY',
     214 : 'POINT',
     215 : 'ROBOT',
     216 : 'PRICK',
     217 : 'WINCE',
     218 : 'CRIMP',
     219 : 'KNOLL',
     220 : 'SUGAR',
     221 : 'WHACK',
     222 : 'MOUNT',
     223 : 'PERKY',
     224 : 'COULD',
     225 : 'WRUNG',
     226 : 'LIGHT',
}

tweets['answer'] = tweets['id'].map(answer_dict)

# %%
first_guess_correct = []
for i, d in tweets.dropna(subset=['answer']).iterrows():
    example_text = d['guess1']
    example_solution = d['answer']
    results =[x.span()[0] for x in re.finditer('🟩', example_text)]
    first_guess_letters = [example_solution[i] for i in results]
    first_guess_correct += first_guess_letters

# %%
pd.Series(first_guess_correct).value_counts(ascending=True) \
    .plot(kind='barh', figsize=(10, 5),
         title='Most Common Correct First Guess Letters',
         edgecolor='black', color=color_pal[5])
plt.show()
